# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -P /content/drive/MyDrive/newFolder/ https://pixeldrain.com/api/file/MbmKs15T?download
# Out:
# --2024-12-19 10:01:02--  https://pixeldrain.com/api/file/MbmKs15T?download
# Resolving pixeldrain.com (pixeldrain.com)... 23.175.1.214, 23.175.1.212, 23.175.1.215, ...
# Connecting to pixeldrain.com (pixeldrain.com)|23.175.1.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10737418240 (10G) [application/x-rar-compressed]
# Saving to: ‘/content/drive/MyDrive/newFolder/MbmKs15T?download’
#
# MbmKs15T?download    80%[===============>    ]   8.06G  1024KB/s    eta 14m 28s
